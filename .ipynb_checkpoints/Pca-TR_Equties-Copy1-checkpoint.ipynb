# %%
import pandas as pd 
import numpy as np
import yfinance as yf
import seaborn as sns
import matplotlib.pyplot as plt 
from ta_utils import *
from sklearn.decomposition import PCA

# %%
#df=getReturn(stocks=stc,s_args={'period':'5y','interval':'1d'}).dropna()
us_stc = ["TSLA","GOOGL","META","AMZN","NVDA"]
df=getReturn(stocks=us_stc,s_args={'period':'5y','interval':'1d'}).dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # PCA

# %%
getComponentDataByStock(df)['PC1'].sort_values().plot(kind='barh',figsize=(12,10))
# Out:
# <Axes: >

# %%
visualizePcaByDate(getComponentDataByDate(df))
# bunun kümülatifini çizdirebiliriz
# PC1 endeksine para yatırsak ne kadar getirimiz olurdu, compound degil naive, ort gün sayısına böl ortalama kazanç.
# kaydırmalı yaparsak belli periodların getirisini ölçebiliriz.

# %% [markdown]
# ## Returns by Different Year Intervals

# %%
df_5=getReturn(stocks=us_stc,s_args={'period':'5y','interval':'1d'}).dropna()
df_1=getReturn(stocks=us_stc,s_args={'period':'1y','interval':'1d'}).dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
s5=getComponentDataByStock(df_5)

# %%
s5
# Out:
#                    PC1       PC2
# Return_TSLA  -0.637463  0.758893
# Return_GOOGL -0.281592 -0.245037
# Return_META  -0.373827 -0.446045
# Return_AMZN  -0.319540 -0.236683
# Return_NVDA  -0.522010 -0.330247

# %%
s1=getComponentDataByStock(df_1)

# %%
s5['PC1'].plot(kind='barh')
# Out:
# <Axes: >

# %%
s1['PC1'].plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# ## PCA Backtesting Returns

# %%
df
# Out:
#             Return_TSLA  Return_GOOGL  Return_META  Return_AMZN  Return_NVDA
# Date
# 2018-11-16     0.016706     -0.002599    -0.030492    -0.016204    -0.207712
# 2018-11-19    -0.002374     -0.038990    -0.058893    -0.052251    -0.127822
# 2018-11-20    -0.017063      0.002945     0.006667    -0.011191     0.029820
# 2018-11-21    -0.027128      0.012518     0.017886     0.014123    -0.029751
# 2018-11-23    -0.037232     -0.012857    -0.023186    -0.009719     0.002002
# ...                 ...           ...          ...          ...          ...
# 2023-11-08    -0.000315      0.006621     0.003007    -0.004424     0.013380
# 2023-11-09    -0.056160     -0.012210     0.002405    -0.010471     0.008041
# 2023-11-10     0.021996      0.017883     0.025320     0.020834     0.029073
# 2023-11-13     0.041342     -0.003778     0.001277    -0.006780     0.005879
# 2023-11-14     0.059438      0.011516     0.021398     0.022262     0.021084
#
# [1256 rows x 5 columns]

# %%
for c in list(df.columns):
    df[f'{c}_cumulative']=df[c].cumsum()

# %%
df
# Out:
#             Return_TSLA  Return_GOOGL  Return_META  Return_AMZN  Return_NVDA  \
# Date
# 2018-11-16     0.016706     -0.002599    -0.030492    -0.016204    -0.207712
# 2018-11-19    -0.002374     -0.038990    -0.058893    -0.052251    -0.127822
# 2018-11-20    -0.017063      0.002945     0.006667    -0.011191     0.029820
# 2018-11-21    -0.027128      0.012518     0.017886     0.014123    -0.029751
# 2018-11-23    -0.037232     -0.012857    -0.023186    -0.009719     0.002002
# ...                 ...           ...          ...          ...          ...
# 2023-11-08    -0.000315      0.006621     0.003007    -0.004424     0.013380
# 2023-11-09    -0.056160     -0.012210     0.002405    -0.010471     0.008041
# 2023-11-10     0.021996      0.017883     0.025320     0.020834     0.029073
# 2023-11-13     0.041342     -0.003778     0.001277    -0.006780     0.005879
# 2023-11-14     0.059438      0.011516     0.021398     0.022262     0.021084
#
#             Return_TSLA_cumulative  Return_GOOGL_cumulative  \
# Date
# 2018-11-16                0.016706                -0.002599
# 2018-11-19                0.014333                -0.041589
# 2018-11-20               -0.002730                -0.038644
# 2018-11-21               -0.029858                -0.026126
# 2018-11-23               -0.067090                -0.038984
# ...                            ...                      ...
# 2023-11-08                2.257757                 0.900927
# 2023-11-09                2.201596                 0.888716
# 2023-11-10                2.223593                 0.906599
# 2023-11-13                2.264935                 0.902821
# 2023-11-14                2.324373                 0.914337
#
#             Return_META_cumulative  Return_AMZN_cumulative  \
# Date
# 2018-11-16               -0.030492               -0.016204
# 2018-11-19               -0.089384               -0.068455
# 2018-11-20               -0.082717               -0.079647
# 2018-11-21               -0.064831               -0.065524
# 2018-11-23               -0.088017               -0.075243
# ...                            ...                     ...
# 2023-11-08                0.798862                0.562287
# 2023-11-09                0.801267                0.551816
# 2023-11-10                0.826587                0.572650
# 2023-11-13                0.827864                0.565870
# 2023-11-14                0.849262                0.588132
#
#             Return_NVDA_cumulative
# Date
# 2018-11-16               -0.207712
# 2018-11-19               -0.335534
# 2018-11-20               -0.305713
# 2018-11-21               -0.335465
# 2018-11-23               -0.333463
# ...                            ...
# 2023-11-08                2.219725
# 2023-11-09                2.227766
# 2023-11-10                2.256839
# 2023-11-13                2.262718
# 2023-11-14                2.283802
#
# [1256 rows x 10 columns]

# %%
pc=getComponentDataByDate(df)

# %%
pc['cumsum1']=pc['PC1'].cumsum()
pc['cumsum2']=pc['PC2'].cumsum()

# %%
pc['cumsum1'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df[[ 'Return_GOOGL_cumulative',
       'Return_META_cumulative', 'Return_AMZN_cumulative',
       'Return_NVDA_cumulative']].plot()
# Out:
# <Axes: xlabel='Date'>
