# %%
import numpy as np
import pandas as pd
import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint, adfuller

import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="whitegrid")

import yfinance as yf
from ta_utils import *
from pprint import *

# %%
start_date = "2020-10-11"
end_date = "2023-11-19"
interval = '1d'

stock1 = "AKBNK.IS"
stock2 = "GARAN.IS"

# %%
s1 = yf.download(stock1, start=start_date, end=end_date, interval=interval)
s2 = yf.download(stock2, start=start_date, end=end_date, interval=interval)

# %%
s2

# %%
#s1['Adj Close']=np.log(s1['Close']/s1['Open'])
#s2['Adj Close']=np.log(s2['Close']/s2['Open'])

# %% [markdown]
# ## Spreading

# %%
#Regression Model
y = np.log(s1['Adj Close'])
x = np.log(s2['Adj Close'])

#y = s1['Adj Close']
#x = s2['Adj Close']

x = sm.add_constant(x)
model = sm.OLS(y,x)
results = model.fit()
results.params

# %%
# Get Spread
alpha = results.params.values[0]
beta = results.params.values[1]
errors = y-(alpha + x['Adj Close']*beta)

# %%
# Charting Spread
errors.plot(label =f"x = {stock1}; y = {stock2} \n{stock2} - {stock1}",figsize=(15,12))
plt.legend()

# %% [markdown]
# ## Dickey Fuller Test

# %%
dftest = adfuller(errors,maxlag=1)
dfoutput = pd.Series(
    dftest[0:4],
    index=["Test Statistic","p-value","#Lags Used","#Observations"]
)
critical_values = pd.Series(dftest[4].values(),index=dftest[4].keys())

print("Dickey Fuller Results")
pprint(dfoutput)
print("\n")
print("Dickey Fuller Critical Values")
pprint(critical_values)
# Out:
# Dickey Fuller Results
# Test Statistic     -1.684818
# p-value             0.438951
# #Lags Used          0.000000
# #Observations     777.000000
# dtype: float64
#
#
# Dickey Fuller Critical Values
# 1%    -3.438794
# 5%    -2.865267
# 10%   -2.568755
# dtype: float64

# %% [markdown]
# ## Z-Score

# %%
spread = errors 
zscore = (spread - np.mean(spread))/np.std(spread)
zscore.plot(label="z-score",figsize=(15,10))

plt.axhline(y=1,color='r',label='1 Th')
plt.axhline(y=-0.5,color='r',label='-1 Th')

plt.legend()

# %% [markdown]
# ## Backtesting

# %%
signal_entry = 1
signal_exit=0

btest = pd.DataFrame()
btest['stock2']=s2['Close']
btest['stock1']=s1['Close']
btest['zscore']=zscore
btest['shortSignal']=(zscore>signal_entry) & (zscore.shift(1)<signal_entry)
btest['shortExit']=(zscore<signal_exit) & (zscore.shift(1)>signal_exit)

btest['longSignal'] = (zscore < -signal_entry) & (zscore.shift(1)> -signal_entry)
btest['longExit'] = (zscore > -signal_exit) & (zscore.shift(1) < -signal_exit)

# %%
spread_side = None
counter = -1
backtest_result = []
indicator = 0

for time, signals_stock in btest.iterrows():
    counter += 1
    # Check if the counter has reached the end of the DataFrame
    if counter >= len(btest):
        break

    stock2_, stock1_, z_score,short_signal, short_exit, long_signal, long_exit = signals_stock
    
    if spread_side == None:
        return_stock2 = 0
        return_stock1 = 0
        backtest_result.append([time, return_stock2, return_stock1, spread_side])
        if short_signal:
            spread_side = "short"
        elif long_signal:
            spread_side = "long"
            
    elif spread_side == "long":
        return_stock2 = btest['stock2'][counter] / btest['stock2'][counter-1] - 1
        return_stock1 = btest['stock1'][counter] / btest['stock1'][counter-1] - 1
        backtest_result.append([time, return_stock2, -return_stock1, spread_side])
        
        if long_exit:
            spread_side = None
                
    elif spread_side == "short":
        return_stock2 = btest['stock2'][counter] / btest['stock2'][counter-1] - 1
        return_stock1 = btest['stock1'][counter] / btest['stock1'][counter-1] - 1
        backtest_result.append([time, -return_stock2, return_stock1, spread_side])
        
        if short_exit:
            spread_side = None

# %%
bt = pd.DataFrame(backtest_result)
bt.columns = ['Date','stock2','stock1','side']
bt['stock2_pl']=np.cumprod(bt['stock2']+1)
bt['stock1_pl']=np.cumprod(bt['stock1']+1)
bt['total_pl']=(bt['stock1_pl']+bt['stock2_pl'])/2
bt.index=bt['Date']

# %%
bt.head(30)
# Out:
#                  Date  stock2  stock1  side  stock2_pl  stock1_pl  total_pl
# Date
# 2020-10-12 2020-10-12     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-13 2020-10-13     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-14 2020-10-14     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-15 2020-10-15     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-16 2020-10-16     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-19 2020-10-19     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-20 2020-10-20     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-21 2020-10-21     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-22 2020-10-22     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-23 2020-10-23     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-26 2020-10-26     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-27 2020-10-27     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-28 2020-10-28     0.0     0.0  None        1.0        1.0       1.0
# 2020-10-30 2020-10-30     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-02 2020-11-02     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-03 2020-11-03     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-04 2020-11-04     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-05 2020-11-05     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-06 2020-11-06     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-09 2020-11-09     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-10 2020-11-10     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-11 2020-11-11     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-12 2020-11-12     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-13 2020-11-13     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-16 2020-11-16     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-17 2020-11-17     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-18 2020-11-18     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-19 2020-11-19     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-20 2020-11-20     0.0     0.0  None        1.0        1.0       1.0
# 2020-11-23 2020-11-23     0.0     0.0  None        1.0        1.0       1.0

# %%
dx = pd.concat([bt,btest],axis=1)

# %%
dx
# Out:
#                  Date    stock2    stock1   side  stock2_pl  stock1_pl  \
# Date
# 2020-10-12 2020-10-12  0.000000  0.000000   None   1.000000   1.000000
# 2020-10-13 2020-10-13  0.000000  0.000000   None   1.000000   1.000000
# 2020-10-14 2020-10-14  0.000000  0.000000   None   1.000000   1.000000
# 2020-10-15 2020-10-15  0.000000  0.000000   None   1.000000   1.000000
# 2020-10-16 2020-10-16  0.000000  0.000000   None   1.000000   1.000000
# ...               ...       ...       ...    ...        ...        ...
# 2023-11-13 2023-11-13  0.024390 -0.052453  short   0.624239   0.436669
# 2023-11-14 2023-11-14 -0.028676  0.016964  short   0.606338   0.444077
# 2023-11-15 2023-11-15  0.010007 -0.031607  short   0.612406   0.430041
# 2023-11-16 2023-11-16 -0.001444  0.001813  short   0.611521   0.430821
# 2023-11-17 2023-11-17  0.009373 -0.011765  short   0.617253   0.425752
#
#             total_pl      stock2      stock1    zscore  shortSignal  \
# Date
# 2020-10-12  1.000000   25.900000   22.219999  1.198175        False
# 2020-10-13  1.000000   26.820000   22.400000  1.078155        False
# 2020-10-14  1.000000   27.400000   22.719999  1.051486        False
# 2020-10-15  1.000000   27.379999   22.900000  1.094910        False
# 2020-10-16  1.000000   27.540001   22.959999  1.081320        False
# ...              ...         ...         ...       ...          ...
# 2023-11-13  0.530454  136.000000  112.000000  2.076664        False
# 2023-11-14  0.525207  139.899994  113.900002  2.031663        False
# 2023-11-15  0.521223  138.500000  110.300003  1.915021        False
# 2023-11-16  0.521171  138.699997  110.500000  1.917562        False
# 2023-11-17  0.521502  137.399994  109.199997  1.900919        False
#
#             shortExit  longSignal  longExit
# Date
# 2020-10-12      False       False     False
# 2020-10-13      False       False     False
# 2020-10-14      False       False     False
# 2020-10-15      False       False     False
# 2020-10-16      False       False     False
# ...               ...         ...       ...
# 2023-11-13      False       False     False
# 2023-11-14      False       False     False
# 2023-11-15      False       False     False
# 2023-11-16      False       False     False
# 2023-11-17      False       False     False
#
# [778 rows x 14 columns]

# %%
# Ploting
bt['total_pl'].plot(label="Evolution P&L")
plt.legend()

# %%
dx.to_excel("dx.xlsx")
