# %%
import pandas as pd 
import numpy as np
import yfinance as yf
import seaborn as sns
import matplotlib.pyplot as plt 
from ta_utils import *

# %%
args_1 = {'period':'1y','interval':'1d'}
args_5 = {'period':'5y','interval':'1d'}

# %% [markdown]
# ## TAV-THY

# %%
findShiftCorrelations("TAVHL.IS","THYAO.IS",args_1)

# %%
getShiftedCorrelation("TAVHL.IS",30,"THYAO.IS",0,args_1)

# %%
# Scatterplot -> lineer bir çizgi yaratıp altında ve üstünde kalan çizgiler önemli , bizi cointegrationa götürcek.
# Pairstrading backtesting lib python

# %%
vizPairShifted("TAVHL.IS",0,"THYAO.IS",1,args_1)

# %%
getPairPlotClose("TAVHL.IS","THYAO.IS",args_1)

# %%
getPairPlotClose("TAVHL.IS","THYAO.IS",args_5)

# %%
getPairPlotReturn("TAVHL.IS","THYAO.IS",args_1)

# %%
df=getReturn(["TAVHL.IS","THYAO.IS"],args_1)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
plot_scatter_with_line(df,"Return_TAVHL.IS","Return_THYAO.IS")

# %% [markdown]
# ## AKBNK - YKBNK

# %%
getPairPlotClose("AKBNK.IS","YKBNK.IS",args_1)

# %%
getPairPlotClose("AKBNK.IS","YKBNK.IS",args_5)

# %%
getPairPlotReturn("AKBNK.IS","YKBNK.IS",args_1)

# %% [markdown]
# ## KOZAA-KOZAL

# %%
getPairPlotClose("KOZAA.IS","KOZAL.IS",args_1)

# %%
getPairPlotClose("KOZAA.IS","KOZAL.IS",args_5)

# %%
getPairPlotReturn("KOZAA.IS","KOZAL.IS",args_1)

# %% [markdown]
# ## KCHOL - SAHOL

# %%
getPairPlotClose("KCHOL.IS","SAHOL.IS",args_1)

# %%
getPairPlotClose("KCHOL.IS","SAHOL.IS",args_5)

# %%
getPairPlotReturn("KCHOL.IS","SAHOL.IS",args_1)

# %% [markdown]
# ## MGROS - SOK

# %%
getPairPlotClose("MGROS.IS","SOKM.IS",args_1)

# %%
getPairPlotClose("MGROS.IS","SOKM.IS",args_5)

# %%
getPairPlotReturn("MGROS.IS","SOKM.IS",args_1)
